# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
def load_error_seq(filename):
    error_seq = [ float(s.strip()) for s in open(filename) if s[0].isdigit() ]
    return range(len(error_seq)),error_seq

# %%
X,Y = load_error_seq('train.lang.log')
plt.plot(X,Y)
